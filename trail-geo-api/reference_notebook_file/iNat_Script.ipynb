# %%
# %pip install pandas
# %pip install geopandas
# %pip install pyproj
# Out:
# Collecting pandas
#   Using cached pandas-2.3.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.3.4-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nkcwa\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\nkcwa\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-2.3.3-cp312-cp312-win_amd64.whl (11.0 MB)
# Downloading numpy-2.3.4-cp312-cp312-win_amd64.whl (12.8 MB)
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ----- ---------------------------------- 1.8/12.8 MB 12.6 MB/s eta 0:00:01
#    --------------------- ------------------ 6.8/12.8 MB 22.1 MB/s eta 0:00:01
#    --------------------- ------------------ 6.8/12.8 MB 22.1 MB/s eta 0:00:01
#    -------------------------- ------------- 8.4/12.8 MB 11.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 9.2/12.8 MB 9.8 MB/s eta 0:00:01
#    ------------------------------- -------- 10.0/12.8 MB 8.7 MB/s eta 0:00:01
#    --------------------------------- ------ 10.7/12.8 MB 7.7 MB/s eta 0:00:01
#    ------------------------------------ --- 11.5/12.8 MB 7.2 MB/s eta 0:00:01
#    -------------------------------------- - 12.3/12.8 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 6.6 MB/s eta 0:00:00
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-2.3.4 pandas-2.3.3 pytz-2025.2 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'c:\Users\nkcwa\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting geopandas
#   Downloading geopandas-1.1.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy>=1.24 in c:\users\nkcwa\appdata\local\programs\python\python312\lib\site-packages (from geopandas) (2.3.4)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Downloading pyogrio-0.11.1-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Requirement already satisfied: packaging in c:\users\nkcwa\appdata\roaming\python\python312\site-packages (from geopandas) (25.0)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\nkcwa\appdata\local\programs\python\python312\lib\site-packages (from geopandas) (2.3.3)
# Collecting pyproj>=3.5.0 (from geopandas)
#   Downloading pyproj-3.7.2-cp312-cp312-win_amd64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas)
#   Downloading shapely-2.1.2-cp312-cp312-win_amd64.whl.metadata (7.1 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nkcwa\appdata\roaming\python\python312\site-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nkcwa\appdata\local\programs\python\python312\lib\site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\nkcwa\appdata\local\programs\python\python312\lib\site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Collecting certifi (from pyogrio>=0.7.2->geopandas)
#   Downloading certifi-2025.10.5-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: six>=1.5 in c:\users\nkcwa\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.17.0)
# Downloading geopandas-1.1.1-py3-none-any.whl (338 kB)
# Downloading pyogrio-0.11.1-cp312-cp312-win_amd64.whl (19.2 MB)
#    ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#    ------ --------------------------------- 3.1/19.2 MB 18.5 MB/s eta 0:00:01
#    ------------- -------------------------- 6.6/19.2 MB 25.2 MB/s eta 0:00:01
#    --------------- ------------------------ 7.6/19.2 MB 13.8 MB/s eta 0:00:01
#    ------------------ --------------------- 8.7/19.2 MB 10.7 MB/s eta 0:00:01
#    ------------------- -------------------- 9.2/19.2 MB 9.7 MB/s eta 0:00:02
#    -------------------- ------------------- 10.0/19.2 MB 8.4 MB/s eta 0:00:02
#    --------------------- ------------------ 10.5/19.2 MB 7.9 MB/s eta 0:00:02
#    ------------------------ --------------- 11.5/19.2 MB 7.1 MB/s eta 0:00:02
#    ------------------------- -------------- 12.3/19.2 MB 6.7 MB/s eta 0:00:02
#    -------------------------- ------------- 12.8/19.2 MB 6.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 13.9/19.2 MB 6.1 MB/s eta 0:00:01
#    ------------------------------ --------- 14.7/19.2 MB 5.9 MB/s eta 0:00:01
#    -------------------------------- ------- 15.5/19.2 MB 5.8 MB/s eta 0:00:01
#    --------------------------------- ------ 16.3/19.2 MB 5.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 17.0/19.2 MB 5.5 MB/s eta 0:00:01
#    ------------------------------------- -- 17.8/19.2 MB 5.4 MB/s eta 0:00:01
#    -------------------------------------- - 18.4/19.2 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 19.2/19.2 MB 5.2 MB/s eta 0:00:00
# Downloading pyproj-3.7.2-cp312-cp312-win_amd64.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ------ --------------------------------- 1.0/6.3 MB 4.6 MB/s eta 0:00:02
#    -------- ------------------------------- 1.3/6.3 MB 4.5 MB/s eta 0:00:02
#    ---------------- ----------------------- 2.6/6.3 MB 3.9 MB/s eta 0:00:01
#    --------------------- ------------------ 3.4/6.3 MB 3.9 MB/s eta 0:00:01
#    -------------------------- ------------- 4.2/6.3 MB 3.9 MB/s eta 0:00:01
#    ------------------------------- -------- 5.0/6.3 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.5/6.3 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 3.8 MB/s eta 0:00:00
# Downloading shapely-2.1.2-cp312-cp312-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------------ --------------- 1.0/1.7 MB 4.6 MB/s eta 0:00:01
#    ------------------------------------ --- 1.6/1.7 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 3.9 MB/s eta 0:00:00
# Downloading certifi-2025.10.5-py3-none-any.whl (163 kB)
# Installing collected packages: shapely, certifi, pyproj, pyogrio, geopandas
# Successfully installed certifi-2025.10.5 geopandas-1.1.1 pyogrio-0.11.1 pyproj-3.7.2 shapely-2.1.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script pyproj.exe is installed in 'c:\Users\nkcwa\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pyproj in c:\users\nkcwa\appdata\local\programs\python\python312\lib\site-packages (3.7.2)
# Requirement already satisfied: certifi in c:\users\nkcwa\appdata\local\programs\python\python312\lib\site-packages (from pyproj) (2025.10.5)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point
from pyproj import CRS
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2 import geopandas as gpd
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# LOAD DATA

# %%
#Load Massachusetts Trail Data
trails = gpd.read_file("MA_State_Trails.geojson")
print("Trail Data Loaded!")
#Set global CRS
PROJECTION = trails.crs
trails.plot()
# Out:
# Trail Data Loaded!
# <Axes: >

# %%
#Select by Name
def get_trail_by_name(geodataframe, name):
    return geodataframe[geodataframe["name"] == name]

# %% [markdown]
# iNaturalist API

# %%
TRAIL_BUFFER = 200 #meters

#Select trail
trail = get_trail_by_name(trails, 'Norwottuck Rail Trail')
trail.plot()
#Add buffer:
trail = trail.to_crs(epsg=5070) #to metered projection
trail = gpd.GeoDataFrame(geometry=trail.buffer(TRAIL_BUFFER), crs=trail.crs)
trail = trail.dissolve()
trail = trail.to_crs(crs=PROJECTION) #back to original CRS
trail.plot()

#Get bounding box
SW_Lng, SW_Lat, NE_Lng, NE_Lat = trail.total_bounds
print(f"Bounding Box, SW: ({SW_Lng}, {SW_Lat}) NE: ({NE_Lng}, {NE_Lat})")

from datetime import datetime
curr_month = datetime.now().month
if curr_month == 1:
    last_month = 12
else:
    last_month = curr_month - 1
if curr_month == 12:
    next_month = 1
else:
    next_month = curr_month + 1

#Send url request
import requests


iNat_url = "https://api.inaturalist.org/v1/observations"
params = {
    "swlng": SW_Lng,
    "swlat": SW_Lat,
    "nelng": NE_Lng,
    "nelat": NE_Lat,      
    "quality_grade": "research",
    "per_page": 200,
    "page": 1,
    "month": [last_month, curr_month, last_month],        
    "year": [2022, 2023, 2024],     # last 3 years
    "order_by": "observed_on"
}

r = requests.get(iNat_url, params=params)
data = r.json()
observations = pd.json_normalize(data["results"])
species = observations["species_guess"]
display(species)
# Out:
# Bounding Box, SW: (-72.62998167323978, 42.329292943867486) NE: (-72.46336871872809, 42.369992539971186)
# 0                 Coral Saucer
# 1               Dryad's Saddle
# 2            flocculose inkcap
# 3                 black locust
# 4      White-breasted Nuthatch
#                 ...
# 195          Resinous Polypore
# 196         Woolly Alder Aphid
# 197        Isabella Tiger Moth
# 198                   Fallfish
# 199         Large Milkweed Bug
# Name: species_guess, Length: 200, dtype: object

# %%
r.url
# Out:
# 'https://api.inaturalist.org/v1/observations?swlng=-72.62998167323978&swlat=42.329292943867486&nelng=-72.46336871872809&nelat=42.369992539971186&quality_grade=research&per_page=200&page=1&month=9&month=10&month=9&year=2022&year=2023&year=2024&order_by=observed_on'
